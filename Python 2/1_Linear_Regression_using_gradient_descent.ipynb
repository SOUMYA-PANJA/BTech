# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def gradient_descent(x,y,alpha=0.01,epoch=30):
  m = np.shape(x)[0]
  n = np.shape(x)[1]
  x = np.concatenate((np.ones((m,1)),x),axis = 1)
  w = np.random.randn(n+1,)
  cost_history_list = []
  for currant_iteration in np.arange(epoch):
    y_estimated = x.dot(w)
    error = y_estimated - y
    cost = (1/2*m)*np.sum(error**2)
    gradient = (1/m)*x.T.dot(error)
    w = w - alpha * gradient
    if currant_iteration % 10 == 0:
      print(f"cost:{cost}\t iteration: {currant_iteration}")
    cost_history_list.append(cost)
  return w, cost_history_list, y_estimated

# %%
rng = np.random.RandomState(10)
x = 10*rng.rand(24,2)
y = 0.9+np.dot(x,[2.2,4])
w, l, h = gradient_descent(x,y,0.001,30)
# Out:
# cost:340418.56799676205	 iteration: 0
# cost:104317.2025475738	 iteration: 10
# cost:34961.65246055	 iteration: 20

# %%
weight, cost_history_list, h = gradient_descent(x,y,0.01,50)

plt.plot(np.arange(len(cost_history_list)), cost_history_list)
plt.xlabel("Number of iteration epoch")
plt.ylabel("Cost function J(Theta)")
plt.title("Gradient descent")
plt.show()
# Out:
# cost:351706.7806880326	 iteration: 0
# cost:280.74050198576384	 iteration: 10
# cost:72.66487633273559	 iteration: 20
# cost:36.579240244144096	 iteration: 30
# cost:29.908836396491484	 iteration: 40

# %%
plt.scatter(np.arange(len(cost_history_list)), cost_history_list)

# %%
plt.plot(h, '.r')
plt.plot(y, 'b')
