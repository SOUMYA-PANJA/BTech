# %% [markdown]
# #### 9. Suppose India has had a GDP growth of 6.45%, 6.86%, 7.20%, 7.92%, 8.45%, and 9.15% consecutively from 2014 to 2019. Also, the inflation for the said period has increased over the rate of 1.63%, 1.80%, 2.72%, 3.45%, 4.12% and 4.36%. Plot a graph using a Python program to show the contrast between these two trends.

# %%
import matplotlib.pyplot as plt
GDP = [6.45, 6.86, 7.20, 7.92, 8.45, 9.15]
Years = list(range(2014, 2020))
inflation = [1.63, 1.80, 2.72, 3.45, 4.12, 4.36]
plt.plot(Years, GDP, label = "GDP", marker = 'd')
plt.plot(Years, inflation, label = "Inflation", marker = 'o')
plt.xlim(2013, 2020)
plt.ylim(0, 10)
plt.xticks(Years, rotation = "vertical")
plt.xlabel("Years")
plt.ylabel("Values out of 100")
plt.legend(loc ="lower right")
plt.show()
