# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    "Data":[
        "Title","Director","Country","Release_Year"
    ],
    "listed_in":[
        123,2341,123,7676
    ]
})
df
# Out:
#            Data  listed_in
# 0         Title        123
# 1      Director       2341
# 2       Country        123
# 3  Release_Year       7676

# %%
df.columns
# Out:
# Index(['Data', 'listed_in'], dtype='object')

# %%
df.size
# Out:
# 8

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
data = ["Movies", "International", "Various", "1980-2010"]
df["new_column"] = data
df
# Out:
#            Data  listed_in     new_column
# 0         Title        123         Movies
# 1      Director       2341  International
# 2       Country        123        Various
# 3  Release_Year       7676      1980-2010

# %%
df['check'] = 1
df
# Out:
#            Data  listed_in     new_column  check
# 0         Title        123         Movies      1
# 1      Director       2341  International      1
# 2       Country        123        Various      1
# 3  Release_Year       7676      1980-2010      1

# %%
df.head(n = 2)
# Out:
#        Data  listed_in     new_column  check
# 0     Title        123         Movies      1
# 1  Director       2341  International      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Data        4 non-null      object
#  1   listed_in   4 non-null      int64
#  2   new_column  4 non-null      object
#  3   check       4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df.loc[1]
# Out:
# Data               Director
# listed_in              2341
# new_column    International
# check                     1
# Name: 1, dtype: object

# %%
df.Data
# Out:
# 0           Title
# 1        Director
# 2         Country
# 3    Release_Year
# Name: Data, dtype: object

# %%
df[["Data", "check","check"]]
# Out:
#            Data  check  check
# 0         Title      1      1
# 1      Director      1      1
# 2       Country      1      1
# 3  Release_Year      1      1

# %%
df["listed_in"].mean()
# Out:
# 2565.75

# %%
df1 = pd.DataFrame({
    "Data":[
        "Title","Director","Country","Release_Year"
    ],
    "Numbers":[
        100,80,50,2010
    ]
}, index = ['A','B','C','D'])
df1
# Out:
#            Data  Numbers
# A         Title      100
# B      Director       80
# C       Country       50
# D  Release_Year     2010

# %%
df1['Numbers'].mean()
# Out:
# 560.0

# %%
df
# Out:
#            Data  listed_in     new_column  check
# 0         Title        123         Movies      1
# 1      Director       2341  International      1
# 2       Country        123        Various      1
# 3  Release_Year       7676      1980-2010      1

# %%
x = pd.melt(df.reset_index(), id_vars="index", value_name=["Data","now_column"])
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-167818e4098c> in <module>()
# ----> 1 x = pd.melt(df.reset_index(), id_vars="index", value_name=["Data","now_column"])
#       2 x
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      58         cols = list(frame.columns)
#      59
# ---> 60     if value_name in frame.columns:
#      61         warnings.warn(
#      62             "This dataframe has a column name that matches the 'value_name' column "
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    4570         False
#    4571         """
# -> 4572         hash(key)
#    4573         try:
#    4574             return key in self._engine
#
# TypeError: unhashable type: 'list'

# %%
df1.set_index("Numbers")
# Out:
#                  Data
# Numbers
# 100             Title
# 80           Director
# 50            Country
# 2010     Release_Year

# %%
df2 = pd.Series(["Good","Bad","Neutral"], index=['A','B','C'])
df3 = pd.Series(np.random.rand(10),index=list(range(1,11)))

# %%
df2
# Out:
# A       Good
# B        Bad
# C    Neutral
# dtype: object

# %%
df3
# Out:
# 1     0.980998
# 2     0.533951
# 3     0.763973
# 4     0.657432
# 5     0.809643
# 6     0.171188
# 7     0.435514
# 8     0.579569
# 9     0.649012
# 10    0.260825
# dtype: float64

# %%
df4 = pd.read_csv('/content/data.csv')
df4.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Data        4 non-null      object
#  1   listed_in   4 non-null      int64
#  2   new_column  4 non-null      object
#  3   check       4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
df4.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df4.sample(5)
# Out:
#      show_id   type                                  title        director  \
# 5218   s5219  Movie  Belief: The Possession of Janet Moses    David Stubbs
# 7105   s7106  Movie                      It's Now or Never    Maria Ripoll
# 2605   s2606  Movie                           Ekşi Elmalar  Yılmaz Erdoğan
# 7405   s7406  Movie       Mark Gatiss: A Study in Sherlock   Nathan Landeg
# 7336   s7337  Movie                        Look Who's Back    David Wnendt
#
#                                                    cast      country  \
# 5218  Kura Forrester, William Davis, Tina Cook, Hari...  New Zealand
# 7105  Dani Rovira, María Valverde, Jordi Sánchez, Jo...        Spain
# 2605  Yılmaz Erdoğan, Farah Zeynep Abdullah, Songül ...       Turkey
# 7405  Benedict Cumberbatch, Martin Freeman, Una Stub...          NaN
# 7336  Oliver Masucci, Fabian Busch, Christoph Maria ...      Germany
#
#             date_added  release_year rating duration  \
# ...

# %%
d = df4[["title","type"]].groupby(["type"])
