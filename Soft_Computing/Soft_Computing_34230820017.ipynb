# %% [markdown]
# # Question 11

# %%
set0 = [0.6, 0.3, 0.7]
set1 = [0.8, 0.4, 0.5]
output = [1, 1, 0]

# %%
def cart(set1, set2):
  res = []

  for i in set1:
    lst = []

    for j in set2:
      lst.append(min(i, j))
    
    res.append(lst)
  
  return res

# %%
cartesion = cart(set0, set1)

# %%
cartesion
# Out:
# [[0.6, 0.4, 0.5], [0.3, 0.3, 0.3], [0.7, 0.4, 0.5]]

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential([tf.keras.layers.Flatten(), tf.keras.layers.Dense(5, activation = 'sigmoid'), 
                             tf.keras.layers.Dense(1, activation = 'sigmoid')])

# %%
model.compile(optimizer = tf.keras.optimizers.SGD(), loss = tf.keras.losses.BinaryCrossentropy(), metrics = ['accuracy'])

# %%
model.layers[1].name
# Out:
# 'dense'

# %%
model.fit(x = np.array(cartesion), y = np.array(output), epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6634 - accuracy: 0.6667
# Epoch 2/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6631 - accuracy: 0.6667
# Epoch 3/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6629 - accuracy: 0.6667
# Epoch 4/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6626 - accuracy: 0.6667
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6624 - accuracy: 0.6667
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6621 - accuracy: 0.6667
# Epoch 7/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6619 - accuracy: 0.6667
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6616 - accuracy: 0.6667
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6614 - accuracy: 0.6667
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6611 - accuracy: 0.6667
# Epoch 11/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6609 - accuracy: 0.6667
# Epoch 12/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6606 - accuracy: 0.6667
# Epoch 13/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6604 - accuracy: 0.6667
# Epoch 14/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6602 - accuracy: 0.6667
# Epoch 15/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6599 - accuracy: 0.6667
# Epoch 16/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6597 - accuracy: 0.6667
# Epoch 17/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6595 - accuracy: 0.6667
# Epoch 18/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6593 - accuracy: 0.6667
# Epoch 19/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6590 - accuracy: 0.6667
# Epoch 20/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6588 - accuracy: 0.6667
# Epoch 21/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6586 - accuracy: 0.6667
# Epoch 22/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6584 - accuracy: 0.6667
# Epoch 23/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6582 - accuracy: 0.6667
# Epoch 24/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6580 - accuracy: 0.6667
# Epoch 25/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6578 - accuracy: 0.6667
# Epoch 26/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6576 - accuracy: 0.6667
# Epoch 27/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6574 - accuracy: 0.6667
# Epoch 28/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6572 - accuracy: 0.6667
# Epoch 29/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6570 - accuracy: 0.6667
# Epoch 30/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6568 - accuracy: 0.6667
# Epoch 31/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6566 - accuracy: 0.6667
# Epoch 32/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6564 - accuracy: 0.6667
# Epoch 33/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6562 - accuracy: 0.6667
# Epoch 34/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6560 - accuracy: 0.6667
# Epoch 35/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6558 - accuracy: 0.6667
# Epoch 36/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6557 - accuracy: 0.6667
# Epoch 37/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6555 - accuracy: 0.6667
# Epoch 38/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6553 - accuracy: 0.6667
# Epoch 39/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6551 - accuracy: 0.6667
# Epoch 40/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6550 - accuracy: 0.6667
# Epoch 41/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6548 - accuracy: 0.6667
# Epoch 42/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6546 - accuracy: 0.6667
# Epoch 43/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6544 - accuracy: 0.6667
# Epoch 44/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6543 - accuracy: 0.6667
# Epoch 45/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6541 - accuracy: 0.6667
# Epoch 46/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6539 - accuracy: 0.6667
# Epoch 47/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6538 - accuracy: 0.6667
# Epoch 48/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6536 - accuracy: 0.6667
# Epoch 49/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6535 - accuracy: 0.6667
# Epoch 50/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6533 - accuracy: 0.6667
# Epoch 51/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6532 - accuracy: 0.6667
# Epoch 52/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6530 - accuracy: 0.6667
# Epoch 53/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6529 - accuracy: 0.6667
# Epoch 54/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6527 - accuracy: 0.6667
# Epoch 55/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6526 - accuracy: 0.6667
# Epoch 56/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6524 - accuracy: 0.6667
# Epoch 57/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6523 - accuracy: 0.6667
# Epoch 58/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6521 - accuracy: 0.6667
# Epoch 59/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6520 - accuracy: 0.6667
# Epoch 60/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6518 - accuracy: 0.6667
# Epoch 61/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6517 - accuracy: 0.6667
# Epoch 62/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6516 - accuracy: 0.6667
# Epoch 63/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6514 - accuracy: 0.6667
# Epoch 64/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6513 - accuracy: 0.6667
# Epoch 65/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6512 - accuracy: 0.6667
# Epoch 66/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6510 - accuracy: 0.6667
# Epoch 67/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6509 - accuracy: 0.6667
# Epoch 68/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6508 - accuracy: 0.6667
# Epoch 69/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6506 - accuracy: 0.6667
# Epoch 70/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6505 - accuracy: 0.6667
# Epoch 71/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6504 - accuracy: 0.6667
# Epoch 72/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6503 - accuracy: 0.6667
# Epoch 73/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.6501 - accuracy: 0.6667
# Epoch 74/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6500 - accuracy: 0.6667
# Epoch 75/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6499 - accuracy: 0.6667
# Epoch 76/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6498 - accuracy: 0.6667
# Epoch 77/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6497 - accuracy: 0.6667
# Epoch 78/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6496 - accuracy: 0.6667
# Epoch 79/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6494 - accuracy: 0.6667
# Epoch 80/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6493 - accuracy: 0.6667
# Epoch 81/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6492 - accuracy: 0.6667
# Epoch 82/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6491 - accuracy: 0.6667
# Epoch 83/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6490 - accuracy: 0.6667
# Epoch 84/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6489 - accuracy: 0.6667
# Epoch 85/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6488 - accuracy: 0.6667
# Epoch 86/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.6487 - accuracy: 0.6667
# Epoch 87/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6486 - accuracy: 0.6667
# Epoch 88/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6485 - accuracy: 0.6667
# Epoch 89/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6484 - accuracy: 0.6667
# Epoch 90/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6483 - accuracy: 0.6667
# Epoch 91/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6482 - accuracy: 0.6667
# Epoch 92/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6481 - accuracy: 0.6667
# Epoch 93/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6480 - accuracy: 0.6667
# Epoch 94/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6479 - accuracy: 0.6667
# Epoch 95/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6478 - accuracy: 0.6667
# Epoch 96/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6477 - accuracy: 0.6667
# Epoch 97/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6476 - accuracy: 0.6667
# Epoch 98/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6475 - accuracy: 0.6667
# Epoch 99/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6474 - accuracy: 0.6667
# Epoch 100/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6473 - accuracy: 0.6667

# %%
model.predict(np.array(cartesion))
# Out:
# 1/1 [==============================] - 0s 20ms/step
# array([[0.6069609 ],
#        [0.59903264],
#        [0.6054056 ]], dtype=float32)

# %%
# def sigmoid(x):
#   return 1/(1 + np.exp(-x))
# def predict(x):
#   if x > 0.5:
#     return 1
#   else:
#     return 0
# def NNF(data, weights1):
#   z1 = np.dot(weights1. data)
#   a1 = sigmoid(z1)
#   out = predict(a1)
#   return out
# def NN(cartesion, output, lr = 0.01):
#   output = np.array(output)
#   data = np.array(cartesion).reshape((-1, 1))
#   num_layer1 = 1
#   weights1 = np.random.randn(num_layer1, data.shape[0])
#   for i in range(100):
#     out = NNF(data, weights1)
#     error = -out*np.log2(out)
#     delta = np.dot((out - output).T.dot(data))

# %% [markdown]
# # Question 4

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np

# %%
k = 3
X, Y = make_blobs(n_samples = 100, n_features = 2, centers = k, cluster_std = 2, random_state = 10)

# %%
X.shape
# Out:
# (100, 2)

# %%
plt.scatter(X[:, 0], X[:, 1], c = Y)

# %%
cluster_centers = [X[np.random.randint(0, X.shape[0]), :] for _ in range(k)]
for i in range(100):
  points = [[] for i in range(k)]

  for data in X:
    dist = [np.sum((data - i)**2)**0.5 for i in cluster_centers]
  
    idx = dist.index(min(dist))
    points[idx].append(data)

  for i in range(k):
    cluster_centers[i] = np.mean(points[i], axis = 0)
  
cluster_centers = np.array(cluster_centers)

# %%
def predict_memberships(clusters, data):
  dist = np.array([1/(np.sum((data - i)**2)**0.5) for i in clusters])
  dist = dist/np.sum(dist)
  dist = np.exp(dist)
  dist = dist/np.sum(dist)
  return dist

# %%
predict_memberships(cluster_centers, X[np.random.randint(0, X.shape[0]), :])
# Out:
# array([0.42163448, 0.31045893, 0.26790659])

# %%
predict_memberships(cluster_centers, X[3, :])
# Out:
# array([0.24769953, 0.51676073, 0.23553973])

# %%
X[3, :]
# Out:
# array([  6.22683284, -10.26022569])

# %%
cluster_centers
# Out:
# array([[ 0.01929006, -5.2349797 ],
#        [ 5.66180367, -9.43779083],
#        [ 3.00804963,  4.74073078]])
